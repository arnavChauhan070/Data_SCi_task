# %% [markdown]
# # Scenario: Predicting Employee Salary Based on Years of Experience
#
# # An HR analytics team wants to predict the salary of employees based on their years of experience.
# # They collected salary data from current employees to build a predictive model.
#
# # They assume a linear relationship:
#
#
# # Salary=m×Experience+b
#
# # Your task is to train a model and predict future salaries.

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error,r2_score
from sklearn.linear_model  import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("salary_lpa - Sheet1 (1).csv")
df
# Out:
#     Experience_years  Salary_lpa
# 0                0.5         3.0
# 1                1.0         3.5
# 2                2.0         4.5
# 3                3.0         5.2
# 4                4.0         6.0
# 5                5.0         6.8
# 6                6.0         7.5
# 7                7.0         8.2
# 8                8.0         9.0
# 9               10.0        10.5
# 10              12.0        12.0

# %%
X = df[["Experience_years"]]
y = df["Salary_lpa"]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2 , random_state = 64+1)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print("Slope ",model.coef_[0])
print("Intercept",model.intercept_)
X_test
df.dtypes
# Out:
# Slope  0.7794744121715077
# Intercept 2.7395020746887964
# Experience_years    float64
# Salary_lpa          float64
# dtype: object

# %%
y_pred = model.predict(X_test)

for actual,pred in zip(y_test.values.flatten(),y_pred):
    print(f" Actual : {actual:.2f} , Predicted : {pred:.2f}")
# Out:
#  Actual : 5.20 , Predicted : 5.08
#  Actual : 4.50 , Predicted : 4.30
#  Actual : 6.00 , Predicted : 5.86

# %%
mae = mean_absolute_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)
print("Mean Square Error ",mae)
print("R2 Score ",r2)
# Out:
# Mean Square Error  0.1554080221300138
# R2 Score  0.9326694302016564

# %%
new_exp = np.array([[26]])
predicted_salary = model.predict(new_exp)
print(f"Experience of 26 years account to ₹{predicted_salary[0]:.2f} LPA")
# Out:
# Experience of 26 years account to ₹23.01 LPA
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(X,y,color = "blue" , label = "Actual Data")
plt.plot(X,model.predict(X),label = "Regression Line")
plt.xlabel("Experience_years")
plt.ylabel("Salary_lpa")
plt.title("House Price Predection using Linear Regression ")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 plt.scatter(X,y,color = "blue" , label = "Actual Data")
#       2 plt.plot(X,model.predict(X),label = "Regression Line")
#       3 plt.xlabel("Area (sqft) ")
#
# NameError: name 'plt' is not defined
